# %% [markdown]
# A video streaming company needs to optimize its Content Delivery Network (CDN) to serve different ISP groups. Given server storage costs, maximum budget, and latency constraints between servers and ISPs, write a MILP to maximize the number of customer groups served while satisfying their data demands and respecting server capacities.
